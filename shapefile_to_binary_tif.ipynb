# %%
import os
import geopandas as gpd
import rasterio
from rasterio import features

# %%
import os
import geopandas as gpd
import rasterio
from rasterio import features

# Define the input folder containing shapefiles
input_folder = 'Monsoon_2012_CRS4326'

# Define the output folder for TIFF files
output_folder = '2012_CRS4326_binary'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
# List all shapefiles in the input folder
shapefile_list = [os.path.join(input_folder, filename) for filename in os.listdir(input_folder) if filename.endswith('.shp')]

# Loop through each shapefile
for shapefile_path in shapefile_list:
    # Generate an output filename based on the input shapefile name
    shapefile_name = os.path.splitext(os.path.basename(shapefile_path))[0]
    output_tiff_path = os.path.join(output_folder, f'{shapefile_name}.tif')

    # Read the shapefile using geopandas
    gdf = gpd.read_file(shapefile_path)

    # Open the raster file you want to use as a template (replace with your raster path)
    template_raster_path = 'sample_EPSG4326.tif'

    with rasterio.open(template_raster_path) as src:
        # Create an empty numpy array for the raster data
        rasterized = features.rasterize(
            [(geom, 1) for geom in gdf.geometry],
            out_shape=src.shape,
            fill=0,
            transform=src.transform,
            all_touched=False,
            default_value=1,
            dtype=rasterio.uint8
        )

        # Create a new raster file and write the rasterized data to it
        with rasterio.open(output_tiff_path, 'w', driver='GTiff', height=src.height, width=src.width, count=1, dtype=rasterio.uint8, crs=src.crs, transform=src.transform) as dst:
            dst.write(rasterized, 1)

    print(f"Raster TIFF file saved at: {output_tiff_path}")
# Out:
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (26JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (28JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (19JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (17JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (02JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (12JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (31AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (20SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (15OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (09JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (24AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (07JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (23JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (11SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (31OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (04SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (24OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (15AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (29AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (04JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (27AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (18OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (16OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (03OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (23SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (11JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (16AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (18AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (07SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (27OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (09SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (29OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (12SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (03AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (20JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (30JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (25JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (01JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (14JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (14SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (05AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (26JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (28JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (10AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (01SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (21OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (05OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (25SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (19JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (17JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (02JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (21AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (10OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (30SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (12JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (09JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (07JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (23JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (04JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (11JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (20JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (02SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (22OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (13AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (30JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (25JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (06AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (08AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (17SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (19SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (13OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (22AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (01JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (14JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (08OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (28SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (06OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (26SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (21JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (10JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (05JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (15JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (07OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (27SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (09OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (29SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (12OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (23AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (09AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (07AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (24JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (18SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (16SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (03SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (23OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (12AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (20AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (03JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (11OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (04OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (24SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (16JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (18JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (11AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (20OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (15SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (29JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (27JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (04AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (22JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (06JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (08JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (13JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (13SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (21JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (02AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (19AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (17AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (08SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (28OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (06SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (26OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (02OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (22SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (10JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (26AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (05JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (28AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (17OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (19OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (15JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (24JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (31JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (03JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (16JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (18JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (29JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (27JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (05SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (25OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (14AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (01AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (22JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (10SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (30OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (14OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (06JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (25AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (08JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (30AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (13JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (01OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_CRS4326_binary/Inundation Boundary (21SEP2012 00 00 00 Value_0).tif

# %%
import pandas as pd
from datetime import datetime

# Read the CSV file into a DataFrame
df = pd.read_csv('GaugeDischarge_Hoshangabad.csv')

# Convert the 'Day' column to datetime format
df['Day'] = pd.to_datetime(df['Day'], format='%d/%m/%y')

# Format the 'Day' column as per the filename format with uppercase month abbreviation
df['filename'] = 'Inundation Boundary (' + df['Day'].dt.strftime('%d%b%Y %H %M %S').str.upper() + ' Value_0).tif'

df.to_csv("GaugeDischarge_Hoshangabad_with_filename.csv")

# Display the updated DataFrame
print(df)
# Out:
#              Day  Mean Gauge (m)  Discharge (cumecs)  \
# 0     1972-09-16           6.543              2941.7
# 1     1972-09-17           5.840              2337.6
# 2     1972-09-18           5.415              1767.5
# 3     1972-09-19           5.000              1350.0
# 4     1972-09-20           5.683              1117.2
# ...          ...             ...                 ...
# 14861 2013-05-27           2.480               126.6
# 14862 2013-05-28           2.490               136.8
# 14863 2013-05-29           2.490               140.9
# 14864 2013-05-30           2.530               146.5
# 14865 2013-05-31           2.540               152.0
#
#                                                 filename
# 0      Inundation Boundary (16SEP1972 00 00 00 Value_...
# 1      Inundation Boundary (17SEP1972 00 00 00 Value_...
# 2      Inundation Boundary (18SEP1972 00 00 00 Value_...
# 3      Inundation Boundary (19SEP1972 00 00 00 Value_...
# 4      Inundation Boundary (20SEP1972 00 00 00 Value_...
# ...                                                  ...
# 14861  Inundation Boundary (27MAY2013 00 00 00 Value_...
# 14862  Inundation Boundary (28MAY2013 00 00 00 Value_...
# 14863  Inundation Boundary (29MAY2013 00 00 00 Value_...
# 14864  Inundation Boundary (30MAY2013 00 00 00 Value_...
# 14865  Inundation Boundary (31MAY2013 00 00 00 Value_...
#
# [14866 rows x 4 columns]

# %% [markdown]
# # Change CRS

# %%
import os
import geopandas as gpd
import rasterio
from rasterio import features

# Define the input folder containing shapefiles
input_folder = 'Monsoon2001_2012/Monsoon_2012'

# Define the output folder for TIFF files
output_folder = '2012_binary_CRS4326'

# Create the output folder if it doesn't exist
if not os.path.exists(output_folder):
    os.makedirs(output_folder)
# List all shapefiles in the input folder
shapefile_list = [os.path.join(input_folder, filename) for filename in os.listdir(input_folder) if filename.endswith('.shp')]

# Loop through each shapefile
for shapefile_path in shapefile_list:
    # Generate an output filename based on the input shapefile name
    shapefile_name = os.path.splitext(os.path.basename(shapefile_path))[0]
    output_tiff_path = os.path.join(output_folder, f'{shapefile_name}.tif')
    
    source_crs = "EPSG:32643"
    # Read the shapefile using geopandas
    gdf = gpd.read_file(shapefile_path, crs=source_crs)
    
    target_crs = "EPSG:4326"
    gdf = gdf.to_crs(target_crs)
    
    # Open the raster file you want to use as a template (replace with your raster path)
    template_raster_path = 'sample_EPSG4326.tif'

    with rasterio.open(template_raster_path) as src:
        # Create an empty numpy array for the raster data
        rasterized = features.rasterize(
            [(geom, 1) for geom in gdf.geometry],
            out_shape=src.shape,
            fill=0,
            transform=src.transform,
            all_touched=False,
            default_value=1,
            dtype=rasterio.uint8
        )

        # Create a new raster file and write the rasterized data to it
        with rasterio.open(output_tiff_path, 'w', driver='GTiff', height=src.height, width=src.width, count=1, dtype=rasterio.uint8, crs=src.crs, transform=src.transform) as dst:
            dst.write(rasterized, 1)

    print(f"Raster TIFF file saved at: {output_tiff_path}")
# Out:
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (26JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (28JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (19JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (17JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (02JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (12JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (31AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (20SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (15OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (09JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (24AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (07JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (23JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (11SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (31OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (04SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (24OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (15AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (29AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (04JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (27AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (18OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (16OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (03OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (23SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (11JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (16AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (18AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (07SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (27OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (09SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (29OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (12SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (03AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (20JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (30JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (25JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (01JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (14JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (14SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (05AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (26JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (28JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (10AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (01SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (21OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (05OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (25SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (19JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (17JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (02JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (21AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (10OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (30SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (12JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (09JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (07JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (23JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (04JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (11JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (20JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (02SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (22OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (13AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (30JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (25JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (06AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (08AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (17SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (19SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (13OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (22AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (01JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (14JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (08OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (28SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (06OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (26SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (21JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (10JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (05JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (15JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (07OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (27SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (09OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (29SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (12OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (23AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (09AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (07AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (24JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (18SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (16SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (03SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (23OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (12AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (20AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (03JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (11OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (04OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (24SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (16JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (18JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (11AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (20OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (15SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (29JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (27JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (04AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (22JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (06JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (08JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (13JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (13SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (21JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (02AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (19AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (17AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (08SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (28OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (06SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (26OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (02OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (22SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (10JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (26AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (05JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (28AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (17OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (19OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (15JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (24JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (31JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (03JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (16JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (18JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (29JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (27JUL2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (05SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (25OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (14AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (01AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (22JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (10SEP2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (30OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (14OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (06JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (25AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (08JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (30AUG2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (13JUN2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (01OCT2012 00 00 00 Value_0).tif
# Raster TIFF file saved at: 2012_binary_CRS4326/Inundation Boundary (21SEP2012 00 00 00 Value_0).tif
